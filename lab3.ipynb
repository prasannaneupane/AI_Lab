# %% [markdown]
# <h3> Cleaning the data

# %%
import pandas as pd

# %%
df=pd.read_csv('student_data.csv')

# %%
print(df.to_string)
# Out:
# <bound method DataFrame.to_string of     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
mydataset={
    'cars':["BMW","Tesla","Lamborgini"],
    'bus':["Micro","Nano","Sumo"]
}
mydataset
# Out:
# {'cars': ['BMW', 'Tesla'], 'bus': ['Micro', 'Nano']}

# %%
data=pd.DataFrame(mydataset)
data
# Out:
#     cars    bus
# 0    BMW  Micro
# 1  Tesla   Nano

# %%
a=[1,7, 2]

# %%
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

# %%
df=pd.read_csv('cleaningdata.csv')

# %%
print(df.to_string)
# Out:
# <bound method DataFrame.to_string of    ID         Name     Age                  Email    JoinDate Salary
# 0   1     John Doe      25     john.doe@email.com  2023-01-15  50000
# 1   2   Jane Smith     NaN   jane.smith@email.com  2023-02-30  60000
# 2   3      Bob Lee  twenty          bob.lee@email  2022/12/01  55000
# 3   4  Alice Brown      30  alice.brown@email.com  2023-03-10    NaN
# 4   5     John Doe      25     john.doe@email.com  2023-01-15  50000
# 5   6          NaN      45         mark@email.com  2023-04-05  70000
# 6   7  Chris Evans      -5  chris.evans@email.com  2023-05-20  65000
# 7   8   Nina Patel      29   nina.patel@email.com  not_a_date  62000
# 8   9   Sam Wilson     120   sam.wilson@email.com  2023-06-01    abc
# 9  10   Jane Smith     NaN   jane.smith@email.com  2023-02-30  60000>

# %%
new_df=df.dropna()

# %%
print(new_df.to_string())
# Out:
#    ID         Name     Age                  Email    JoinDate Salary
# 0   1     John Doe      25     john.doe@email.com  2023-01-15  50000
# 2   3      Bob Lee  twenty          bob.lee@email  2022/12/01  55000
# 4   5     John Doe      25     john.doe@email.com  2023-01-15  50000
# 6   7  Chris Evans      -5  chris.evans@email.com  2023-05-20  65000
# 7   8   Nina Patel      29   nina.patel@email.com  not_a_date  62000
# 8   9   Sam Wilson     120   sam.wilson@email.com  2023-06-01    abc

# %%
df = pd.read_csv('cleaningdata.csv')
new_df = df.dropna()
print(new_df.to_string())
# Out:
#    ID         Name     Age                  Email    JoinDate Salary
# 0   1     John Doe      25     john.doe@email.com  2023-01-15  50000
# 2   3      Bob Lee  twenty          bob.lee@email  2022/12/01  55000
# 4   5     John Doe      25     john.doe@email.com  2023-01-15  50000
# 6   7  Chris Evans      -5  chris.evans@email.com  2023-05-20  65000
# 7   8   Nina Patel      29   nina.patel@email.com  not_a_date  62000
# 8   9   Sam Wilson     120   sam.wilson@email.com  2023-06-01    abc
